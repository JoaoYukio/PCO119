# %%
import control

# %%
import numpy as np

# %%
num1 = np.array([0.0001471, 0.0005194, 0.0001146])
den1 = np.array([1,-2.534,2.145,-0.6065])
dt1 = 0.1
gz1 = control.TransferFunction(num1,den1, dt1)
gz1
# Out:
# TransferFunction(array([0.0001471, 0.0005194, 0.0001146]), array([ 1.    , -2.534 ,  2.145 , -0.6065]), 0.1)

# %%
control.poles(gz1)
# Out:
# array([0.84843808+0.06824469j, 0.84843808-0.06824469j,
#        0.83712385+0.j        ])

# %%
control.zeros(gz1)
# Out:
# array([-3.29445461+0.j, -0.23647673+0.j])

# %%
from control.matlab import pzmap

# %%
pzmap(gz1)
# Out:
# (array([0.84843808+0.06824469j, 0.84843808-0.06824469j,
#         0.83712385+0.j        ]),
#  array([-3.29445461+0.j, -0.23647673+0.j]))

# %%
poles1 = abs(control.poles(gz1))

# %%
poles1
# Out:
# array([0.85117831, 0.85117831, 0.83712385])

# %%
import matplotlib.pyplot as plt

# %%
yout1, T1 = control.step_response(gz1)

# %%
plt.grid()
plt.title("Resposta do sistema 1 ao degrau")
plt.plot(yout1, T1)

# %%
num2 = np.array([0.0001548,0.0005752,0.0001332])
den2 = np.array([1,-2.734,2.471,-0.7408])
dt2 = 0.1
gz2 = control.TransferFunction(num2, den2, dt2)
gz2
# Out:
# TransferFunction(array([0.0001548, 0.0005752, 0.0001332]), array([ 1.    , -2.734 ,  2.471 , -0.7408]), 0.1)

# %%
from matplotlib import patches

# %%
pzmap(gz2)
# Out:
# (array([1.09812074+0.j        , 0.81793963+0.07471157j,
#         0.81793963-0.07471157j]),
#  array([-3.46761938+0.j, -0.2481429 +0.j]))

# %%
poles2 = abs(control.poles(gz2))
poles2
# Out:
# array([1.09812074, 0.82134466, 0.82134466])

# %%
yout2, T2 = control.step_response(gz2) #Sistema instavel, |polo| > 1

# %%
plt.grid()
plt.title("Resposta ao degrau do segundo sistema sistema")
plt.plot(yout2, T2, color='orange')

# %%
1.5699443815868492 * 0.3
# Out:
# 0.47098331447605474
