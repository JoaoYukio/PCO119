# %%
import control

# %%
#Teste da solução (Pode estar errado)
num = [10,0]
den = [100,170,26,1]
Vo = control.TransferFunction(num, den)
Vo
# Out:
# TransferFunction(array([10,  0]), array([100, 170,  26,   1]))

# %%
yout, T = control.step_response(Vo)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(yout, T)
