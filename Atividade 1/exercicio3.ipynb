# %%
import control # pip3 install control

# %%
num = [10,1]
den = [100,170,46,1]
Vo = control.TransferFunction(num, den)
Vo
# Out:
# TransferFunction(array([10,  1]), array([100, 170,  46,   1]))

# %%
num = [1]
den = [1, 1.2, 1]
Vs = control.TransferFunction(num, den)

# %%
yout, T = control.step_response(Vs)

# %%
import matplotlib.pyplot as plt
#Para funcionar precisa rodar no jupyter Notebook, use o promt/terminal para iniciar o jupyter 
#Abra o projeto no git no VS Code e rode:
#pip install jupyterlab <- caso nao tenha o jupyter
#pip install notebook <- caso nao tenha o jupyter
# Rode: jupyter notebook
# %matplotlib notebook

# %%
plt.plot(yout, T)
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
control.pole(Vo)
control.margin(Vs)
# Out:
# (inf, 116.1038811373399, nan, 0.7483314773547883)

# %%
control.bode(Vs)
# Out:
# (array([1.0027614 , 1.00278661, 1.00281205, 1.00283771, 1.00286361,
#         1.00288974, 1.00291611, 1.00294271, 1.00296955, 1.00299663,
#         1.00302396, 1.00305153, 1.00307935, 1.00310741, 1.00313573,
#         1.0031643 , 1.00319313, 1.00322221, 1.00325156, 1.00328116,
#         1.00331103, 1.00334117, 1.00337158, 1.00340226, 1.00343321,
#         1.00346444, 1.00349595, 1.00352774, 1.00355981, 1.00359217,
#         1.00362482, 1.00365775, 1.00369098, 1.00372451, 1.00375833,
#         1.00379245, 1.00382688, 1.00386161, 1.00389665, 1.00393201,
#         1.00396767, 1.00400365, 1.00403995, 1.00407657, 1.00411352,
#         1.00415079, 1.0041884 , 1.00422633, 1.0042646 , 1.00430321,
#         1.00434216, 1.00438145, 1.00442109, 1.00446107, 1.00450141,
#         1.00454211, 1.00458316, 1.00462458, 1.00466635, 1.0047085 ,
#         1.00475101, 1.0047939 , 1.00483717, 1.00488081, 1.00492484,
#         1.00496925, 1.00501405, 1.00505924, 1.00510483, 1.00515081,
# ...
