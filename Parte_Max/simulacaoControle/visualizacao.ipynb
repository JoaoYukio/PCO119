# %% [markdown]
# Teste feito para um controlador PI em serie com um controlador PD

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = open("outputPD.txt", "r")
arrPD = f.read().split(',')
len(arrPD)
arrPD = arrPD[:len(arrPD)-2]#O ultimo carectere é um espaço em branco

arrPD = [float(x) for x in arrPD]

# %%
fI = open("outputPI.txt", "r")
arrPI = fI.read().split(',')
len(arrPI)
arrPI = arrPI[:len(arrPI)-2]#O ultimo carectere é um espaço em branco
arrPI = [float(x) for x in arrPI]

# %%
#Cria um degrau 
deg  = []
for i in range(0,3000):
    if i < 10:
        deg.append(0)
    else:
        deg.append(1)

# %%
plt.plot(arrPI)

# %%
plt.plot(arrPD)
plt.plot(deg)

# %% [markdown]
# Teste com os controladores individuais

# %%
#Controlador PI
fSI = open("outSoloPI.txt", "r")
arrSPI = fSI.read().split(',')
arrSPI = arrSPI[:len(arrSPI)-2]#O ultimo carectere é um espaço em branco
arrSPI = [float(x) for x in arrSPI]

# %%
#Controlador PI eqDif
fSI = open("eqDifPI.txt", "r")
arrSPI = fSI.read().split(',')
arrSPI = arrSPI[:len(arrSPI)-2]#O ultimo carectere é um espaço em branco
arrSPI = [float(x) for x in arrSPI]

# %%
plt.plot(arrSPI, label = "Controlador eq PI 0.5, 0.2")

# %%
plt.plot(arrSPI, label = "Controlador PI 0.5, 0.2")

# %%
plt.plot(arrSPI, label = "Controlador PI 0.8, 0.4")

# %%
plt.plot(arrSPI, label = "Controlador PI 0.8, 1")

# %%
plt.plot(arrSPI, label = "Controlador PI 0.9, 1.7")

# %%
plt.plot(arrSPI, label = "Controlador PI 0.9, 1.2")

# %%
plt.plot(arrSPI, label = "Controlador PI 0.8, 1.5")

# %% [markdown]
# Controlador PD

# %%
fSD = open("outSoloPD.txt", "r")
arrSPD = fSD.read().split(',')
arrSPD = arrSPD[:len(arrSPD)-2]#O ultimo carectere é um espaço em branco
arrSPD = [float(x) for x in arrSPD]

# %%
plt.plot(arrSPD, label = "Controlador PD 0.3, 0.01")

# %%
plt.plot(arrSPD, label = "Controlador PD 0.5, 0.02")

# %%
plt.plot(arrSPD, label = "Controlador PD 1, 0.02")

# %%
plt.plot(arrSPD, label = "Controlador PD 0.8, 0.01")

# %% [markdown]
# Usando eq. Dif com float

# %%
f = open("eqDifPD.txt", "r")
arrPDeq = f.read().split(',')
len(arrPDeq)
arrPDeq = arrPDeq[:len(arrPDeq)-2]#O ultimo carectere é um espaço em branco

arrPD = [float(x) for x in arrPDeq]

# %%
plt.plot(arrPDeq, label = "Controlador PD eqDif 0.3, 0.01")
plt.legend()

# %%
fSD = open("outSoloPD.txt", "r")
arrSPD = fSD.read().split(',')
arrSPD = arrSPD[:len(arrSPD)-2]#O ultimo carectere é um espaço em branco
arrSPD = [float(x) for x in arrSPD]

# %%
plt.plot(arrSPD, label = "Controlador PD 0.3, 0.01")

# %%
#Comparando os resultados
plt.plot(arrSPD, label = "Controlador PD 0.3, 0.01")
plt.plot(arrPDeq, label = "Controlador PD eqDif 0.3, 0.01")

plt.legend()

# %%
#Comparacao entre os PIs
f = open("eqDifPI.txt", "r")
arrPIeq = f.read().split(',')
len(arrPIeq)
arrPIeq = arrPIeq[:len(arrPIeq)-2]#O ultimo carectere é um espaço em branco

arrPI = [float(x) for x in arrPIeq]

# %%
#Controlador PI eqDif
fSI = open("outSoloPI.txt", "r")
arrSPI = fSI.read().split(',')
arrSPI = arrSPI[:len(arrSPI)-2]#O ultimo carectere é um espaço em branco
arrSPI = [float(x) for x in arrSPI]

# %%
#Controlador PI eqDif
fSI2 = open("outSoloPIgetControl.txt", "r")
arrSPI2 = fSI2.read().split(',')
arrSPI2 = arrSPI2[:len(arrSPI2)-2]#O ultimo carectere é um espaço em branco
arrSPI2 = [float(x) for x in arrSPI2]

# %%
plt.plot(arrSPI2, label = "Controlador PI 0.5, 0.2")

# %%
plt.plot(arrSPI, label = "Controlador PI 0.5, 0.2")

# %%
plt.plot(arrPIeq, label = "Controlador eq PI 0.5, 0.2")
